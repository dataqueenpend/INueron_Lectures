# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Creating random Dataframe with 1000 instances and 1 column
df1 = pd.DataFrame(np.random.rand(1000, 1), index=pd.date_range('2021-07-18', periods=1000), columns=['data'])
df1
# Out:
#                 data
# 2021-07-18  0.666080
# 2021-07-19  0.830782
# 2021-07-20  0.500182
# 2021-07-21  0.566491
# 2021-07-22  0.637537
# ...              ...
# 2024-04-08  0.411574
# 2024-04-09  0.243884
# 2024-04-10  0.047867
# 2024-04-11  0.318751
# 2024-04-12  0.192152
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Basic visualization

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df1.data.cumsum()
# Out:
# 2021-07-18      0.666080
# 2021-07-19      1.496862
# 2021-07-20      1.997044
# 2021-07-21      2.563535
# 2021-07-22      3.201072
#                  ...
# 2024-04-08    511.452040
# 2024-04-09    511.695924
# 2024-04-10    511.743790
# 2024-04-11    512.062542
# 2024-04-12    512.254694
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df1['data1'] = df1.data.cumsum()
df1['data2'] = df1['data'].apply(lambda x: x *3)
df1
# Out:
#                 data       data1     data2
# 2021-07-18  0.666080    0.666080  1.998240
# 2021-07-19  0.830782    1.496862  2.492347
# 2021-07-20  0.500182    1.997044  1.500545
# 2021-07-21  0.566491    2.563535  1.699474
# 2021-07-22  0.637537    3.201072  1.912611
# ...              ...         ...       ...
# 2024-04-08  0.411574  511.452040  1.234722
# 2024-04-09  0.243884  511.695924  0.731652
# 2024-04-10  0.047867  511.743790  0.143600
# 2024-04-11  0.318751  512.062542  0.956253
# 2024-04-12  0.192152  512.254694  0.576456
#
# [1000 rows x 3 columns]

# %%
df1.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Loading Iris dataset from Seaborn

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(figsize=(20, 15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plot is putting indexes on x axis.

# %%
iris.plot(figsize=(10,10), title='Iris Dataset')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}>

# %%
gf = iris.plot(figsize=(10,10), title='Iris dataset')
gf.set_xlabel('Indexes')
gf.set_ylabel('Numbers')
# Out:
# Text(0, 0.5, 'Numbers')

# %%
iris.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Loading titanic from Seaborn

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Another random DataFrame

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.587735  0.080835  0.847466  0.623985
# 1  0.632753  0.295717  0.081983  0.963146
# 2  0.766275  0.349215  0.571851  0.227772
# 3  0.442808  0.882342  0.590933  0.562962
# 4  0.517692  0.262365  0.872486  0.198231
# 5  0.199268  0.235458  0.203077  0.272438
# 6  0.859739  0.812207  0.847160  0.773020
# 7  0.609903  0.005338  0.827280  0.100110
# 8  0.905581  0.892337  0.063320  0.720867
# 9  0.531759  0.071302  0.951960  0.444819

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Pandas Histograms

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=True, bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=True, bins=100, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist(figsize=(10,10), color='r', alpha=.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Pandas for Bivariate Analysis, Multivariate Analysis (Correlations)

# %% [markdown]
# ### Scatterplot

# %%
iris.plot.scatter(x='sepal_width', y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
iris.plot.scatter(x='sepal_length', y='petal_width', c = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width', s=80, c='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.hexbin(x='sepal_length', y='sepal_width', gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Pie plots

# %%
df
# Out:
#           a         b         c         d
# 0  0.587735  0.080835  0.847466  0.623985
# 1  0.632753  0.295717  0.081983  0.963146
# 2  0.766275  0.349215  0.571851  0.227772
# 3  0.442808  0.882342  0.590933  0.562962
# 4  0.517692  0.262365  0.872486  0.198231
# 5  0.199268  0.235458  0.203077  0.272438
# 6  0.859739  0.812207  0.847160  0.773020
# 7  0.609903  0.005338  0.827280  0.100110
# 8  0.905581  0.892337  0.063320  0.720867
# 9  0.531759  0.071302  0.951960  0.444819

# %%
d = df1.iloc[0]
d
# Out:
# data     0.66608
# data1    0.66608
# data2    1.99824
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
iris1 = iris.head(3).T

# %%
iris1.iloc[0:4].plot.pie(subplots=True, figsize=(20,20), fontsize=20, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %% [markdown]
# ### Plotting relationships - all-to-all - scatter_matixes

# %%
pd.plotting.scatter_matrix(df1, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='data', ylabel='data'>,
#         <AxesSubplot:xlabel='data1', ylabel='data'>,
#         <AxesSubplot:xlabel='data2', ylabel='data'>],
#        [<AxesSubplot:xlabel='data', ylabel='data1'>,
#         <AxesSubplot:xlabel='data1', ylabel='data1'>,
#         <AxesSubplot:xlabel='data2', ylabel='data1'>],
#        [<AxesSubplot:xlabel='data', ylabel='data2'>,
#         <AxesSubplot:xlabel='data1', ylabel='data2'>,
#         <AxesSubplot:xlabel='data2', ylabel='data2'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(15,15))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(iris, figsize=(15,15), diagonal='kde') # Scatter matrix with kde on diagonal
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %% [markdown]
# ## Additional beautification options for Pandas Plots

# %%
df1['data'].plot(style='r--', legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Plotly plots

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Config for offline mode
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.iplot()
# Out:
# <div>                            <div id="0ec71671-a807-4744-a94d-6a4a44f69e02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
titanic.iplot(kind='scatter', x='fare', y='age', mode='markers', xTitle='Fare', yTitle='Age')
# Out:
# <div>                            <div id="0bd75547-fc2d-4755-ac32-c72dec6b7f1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Themes in Plotly

# %%
cf.getThemes() # Checking available themes
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
cf.getTheme() # Actual theme
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
# Setting new theme

# %%
cf.set_config_file(theme='ggplot')
titanic.iplot(kind='scatter', x='fare', y='age', mode='markers', xTitle='Fare', yTitle='Age')
# Out:
# <div>                            <div id="7d2e0ff1-0e7a-4209-83c8-f139c6dc8b07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
